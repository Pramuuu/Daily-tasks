# %% [markdown]
# <a href="https://colab.research.google.com/github/Pramuuu/Daily-tasks/blob/main/01_07_24_python_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df= pd.DataFrame(
    {
        "a":[4,5,6],
        "b": [7,8,9],
        "c": [10,11,12]
    },
    index = [1,2,3]
)

# %%
import pandas as pd
df = pd.DataFrame(
[[4, 7, 10],
[5, 8, 11],
[6, 9, 12]],
index=[1, 2, 3],
columns=['a', 'b', 'c'])

# %%
#Create DataFrame with a MultiIndex
df = pd.DataFrame(
{"a" : [4 ,5, 6],
"b" : [7, 8, 9],
"c" : [10, 11, 12]},
index = pd.MultiIndex.from_tuples(
[('d',1),('d',2),('e',2)],
names=['n','v']))

# %%
#Reshaping Data: Change the layout of a data set:
#columns into rows
pd.melt(df)
# Out:
#   variable  value
# 0        a      4
# 1        a      5
# 2        a      6
# 3        b      7
# 4        b      8
# 5        b      9
# 6        c     10
# 7        c     11
# 8        c     12
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['value'].plot(kind='hist', bins=20, title='value')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('variable').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
#Append columns of DataFrames
pd.concat([df], axis=1)
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12

# %%
#Rename the columns of a DataFrame
df.rename(columns = {'y':'year'})
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12

# %%
#Sort the index of a DataFrame
df.sort_index()
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12

# %%
#Remove duplicate rows (only considers columns).
df.drop_duplicates()
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12

# %%
import matplotlib as plot #plotting
import pandas as pd
df = pd.DataFrame({'X':[78,85,96,80,86], 'Y':[84,94,89,83,86],'Z':[86,97,96,72,83]});
print(df)
df.plot.hist()
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96
# 3  80  83  72
# 4  86  86  83
# <Axes: ylabel='Frequency'>

# %%
 # Scatter chart using pairs of points
import matplotlib.pyplot as plt
from pylab import randn
X = randn(200)
Y = randn(200)
plt.scatter(X,Y, color='r')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
#object creation
import numpy as np
import pandas as pd
s = pd.Series([1, 4, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    4.0
# 2    NaN
# 3    6.0
# 4    8.0
# dtype: float64

# %%
#using numpy array
dates = pd.date_range('20190101', periods=8)
dates
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(8, 4), index=dates, columns=list('PQRS'))
df
# Out:
#                    P         Q         R         S
# 2019-01-01  0.993705 -0.748536 -0.315363 -0.920944
# 2019-01-02 -1.100633 -0.788448 -0.223787  0.633858
# 2019-01-03  1.065025  0.072024 -0.945031  0.575548
# 2019-01-04 -0.638182 -0.621396  0.889315 -0.094805
# 2019-01-05 -0.776013 -0.841436  1.672904 -0.854826
# 2019-01-06 -0.097389  1.677841  1.157899 -1.221170
# 2019-01-07  0.498321 -1.261690 -0.590195  0.407982
# 2019-01-08 -1.358114 -0.115925  0.922687  0.103272

# %%
df2 = pd.DataFrame({'A': 1.,
                        'B': pd.Timestamp('20190102'),
                        'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                        'D': np.array([3] * 4, dtype='int32'),
                        'E': pd.Categorical(["test", "train", "test", "train"]),
                        'F': 'foo'})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2019-01-02  1.0  3   test  foo
# 1  1.0 2019-01-02  1.0  3  train  foo
# 2  1.0 2019-01-02  1.0  3   test  foo
# 3  1.0 2019-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
import numpy as np
import pandas as pd
dates = pd.date_range('20190101', periods=8)
df = pd.DataFrame(np.random.randn(8, 4), index=dates, columns=list('PQRS'))
df.head()
# Out:
#                    P         Q         R         S
# 2019-01-01 -0.983687 -0.958866  1.141028  1.615854
# 2019-01-02 -2.017474 -0.542083  1.303229  0.050658
# 2019-01-03  0.112553  0.422429 -0.731098 -0.539693
# 2019-01-04  1.799686 -0.255103 -0.279958 -1.359319
# 2019-01-05 -0.897479 -0.229732 -0.012386 -0.235000

# %%
df.tail(3)
# Out:
#                    P         Q         R         S
# 2019-01-06 -0.253768  0.919555  0.216563 -1.164752
# 2019-01-07  1.727269 -1.341842  0.507929 -1.110343
# 2019-01-08 -1.287312  0.523210  0.373754 -0.167675

# %%
df.index
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['P', 'Q', 'R', 'S'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-0.98368729, -0.95886559,  1.14102789,  1.61585387],
#        [-2.01747417, -0.54208276,  1.30322875,  0.05065846],
#        [ 0.11255282,  0.42242918, -0.73109795, -0.5396932 ],
#        [ 1.79968643, -0.25510327, -0.27995836, -1.35931915],
#        [-0.89747884, -0.22973229, -0.01238576, -0.23500015],
#        [-0.25376848,  0.91955543,  0.21656332, -1.16475178],
#        [ 1.72726883, -1.34184196,  0.50792911, -1.11034251],
#        [-1.28731228,  0.52321006,  0.37375443, -0.16767539]])

# %%
df.describe()
# Out:
#               P         Q         R         S
# count  8.000000  8.000000  8.000000  8.000000
# mean  -0.225027 -0.182804  0.314883 -0.363784
# std    1.383308  0.771095  0.682931  0.953693
# min   -2.017474 -1.341842 -0.731098 -1.359319
# 25%   -1.059594 -0.646278 -0.079279 -1.123945
# 50%   -0.575624 -0.242418  0.295159 -0.387347
# 75%    0.516232  0.447624  0.666204 -0.113092
# max    1.799686  0.919555  1.303229  1.615854

# %%
df.T
# Out:
#    2019-01-01  2019-01-02  2019-01-03  2019-01-04  2019-01-05  2019-01-06  \
# P   -0.983687   -2.017474    0.112553    1.799686   -0.897479   -0.253768
# Q   -0.958866   -0.542083    0.422429   -0.255103   -0.229732    0.919555
# R    1.141028    1.303229   -0.731098   -0.279958   -0.012386    0.216563
# S    1.615854    0.050658   -0.539693   -1.359319   -0.235000   -1.164752
#
#    2019-01-07  2019-01-08
# P    1.727269   -1.287312
# Q   -1.341842    0.523210
# R    0.507929    0.373754
# S   -1.110343   -0.167675

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    S         R         Q         P
# 2019-01-01  1.615854  1.141028 -0.958866 -0.983687
# 2019-01-02  0.050658  1.303229 -0.542083 -2.017474
# 2019-01-03 -0.539693 -0.731098  0.422429  0.112553
# 2019-01-04 -1.359319 -0.279958 -0.255103  1.799686
# 2019-01-05 -0.235000 -0.012386 -0.229732 -0.897479
# 2019-01-06 -1.164752  0.216563  0.919555 -0.253768
# 2019-01-07 -1.110343  0.507929 -1.341842  1.727269
# 2019-01-08 -0.167675  0.373754  0.523210 -1.287312

# %%
df.sort_values(by='Q')
# Out:
#                    P         Q         R         S
# 2019-01-07  1.727269 -1.341842  0.507929 -1.110343
# 2019-01-01 -0.983687 -0.958866  1.141028  1.615854
# 2019-01-02 -2.017474 -0.542083  1.303229  0.050658
# 2019-01-04  1.799686 -0.255103 -0.279958 -1.359319
# 2019-01-05 -0.897479 -0.229732 -0.012386 -0.235000
# 2019-01-03  0.112553  0.422429 -0.731098 -0.539693
# 2019-01-08 -1.287312  0.523210  0.373754 -0.167675
# 2019-01-06 -0.253768  0.919555  0.216563 -1.164752

# %%
import numpy as np
import pandas as pd
dates = pd.date_range('20190101', periods=8)
df = pd.DataFrame(np.random.randn(8, 4), index=dates, columns=list('PQRS'))
df.mean()
# Out:
# P   -0.207492
# Q   -0.442351
# R   -0.409291
# S   -0.418813
# dtype: float64

# %%
df.mean(1)
# Out:
# 2019-01-01   -0.304488
# 2019-01-02    0.813189
# 2019-01-03   -0.634756
# 2019-01-04   -0.432151
# 2019-01-05   -0.203296
# 2019-01-06   -0.805055
# 2019-01-07   -0.289727
# 2019-01-08   -1.099608
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 4, np.nan, 6, 8]).shift(2)
s
# Out:
# 0    NaN
# 1    NaN
# 2    1.0
# 3    4.0
# 4    NaN
# dtype: float64

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# P    1.380326
# Q    2.425138
# R    3.791141
# S    3.005816
# dtype: float64

# %%
s = pd.Series(np.random.randint(0, 5, size=8))
s
# Out:
# 0    3
# 1    2
# 2    2
# 3    4
# 4    2
# 5    0
# 6    0
# 7    2
# dtype: int64

# %%
s = pd.Series(['C', 'D', 'Baca', np.nan, 'CABA', 'dog', 'boy'])
s.str.lower()
# Out:
# 0       c
# 1       d
# 2    baca
# 3     NaN
# 4    caba
# 5     dog
# 6     boy
# dtype: object
